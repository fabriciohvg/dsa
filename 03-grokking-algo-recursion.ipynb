# %% [markdown]
# Recursion
#
# Factorial function with recursion

# %%
def factorial(number):
  if number == 1:
    return 1
  else:
    return number * factorial(number - 1)

factorial(5)
# Out:
# 120
